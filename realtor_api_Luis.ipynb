# %%
import requests
import pandas as pd
import json

url = "https://realtor.p.rapidapi.com/properties/v2/list-for-sale"
querystring = {"city":"New York City","limit":"200","offset":"0","state_code":"NY","sort":"relevance"}

headers = {
    'x-rapidapi-key': "bdc2d05badmsh9afadba2f12e067p1e1e49jsn9596022c7263",
    'x-rapidapi-host': "realtor.p.rapidapi.com"
    }

# json = response.json()
# df = pd.DataFrame.from_dict(json)
response = requests.request("GET", url, headers=headers, params=querystring).json()

# %%
for dict_ in response:
    print(dict_)
# Out:
# meta
# properties

# %%
# keys = list(response.keys())
keys = [*response.keys()] 
#print keys
print(keys)
# Out:
# ['meta', 'properties']

# %%
# for value in response
# response['properties'][0]['address']['lat']
prop_type =[]
city=[]
lat=[]
lon= []
price=[]
building_size = []
county_=[]
postal_code=[]
search_key='building_size'
for s in range(len(response['properties'])):
#     print(f"The Address. {response[s]['address']}")
    print(f' prop_type: {response["properties"][s]["prop_type"]} postal_code: {response["properties"][s]["address"]["postal_code"]}\
    Lat: {response["properties"][s]["address"]["lat"]}, Lon: {response["properties"][s]["address"]["lon"]}')
    prop_type.append(response["properties"][s]["prop_type"])
#     county_.append(response["properties"][s]["address"]["county"])
    lat.append(response["properties"][s]["address"]["lat"])
    lon.append(response["properties"][s]["address"]["lon"])
    price.append(response["properties"][s]["price"])
    city.append(response["properties"][s]["address"]["city"])
    
    if search_key in response["properties"][s].keys():
        postal_code.append(response["properties"][s]["address"]["postal_code"])
    else:
        postal_code.append('NA')
        
    if search_key in response["properties"][s].keys():
        building_size.append(response["properties"][s]["building_size"]["size"])
    else:
        building_size.append('NA')
# Out:
#  prop_type: condo postal_code: 11238    Lat: 40.67532, Lon: -73.958316
#  prop_type: single_family postal_code: 11412    Lat: 40.698966, Lon: -73.76892
#  prop_type: single_family postal_code: 11375    Lat: 40.709773, Lon: -73.855658
#  prop_type: single_family postal_code: 10306    Lat: 40.572692, Lon: -74.115587
#  prop_type: condo postal_code: 11364    Lat: 40.746345, Lon: -73.75674
#  prop_type: condo postal_code: 10011    Lat: 40.739832, Lon: -73.998338
#  prop_type: multi_family postal_code: 11416    Lat: 40.681654, Lon: -73.857591
#  prop_type: condo postal_code: 10128    Lat: 40.780412, Lon: -73.952251
#  prop_type: multi_family postal_code: 11416    Lat: 40.685067, Lon: -73.844102
#  prop_type: multi_family postal_code: 11221    Lat: 40.686089, Lon: -73.942938
#  prop_type: condo postal_code: 10009    Lat: 40.728143, Lon: -73.980474
#  prop_type: condo postal_code: 10019    Lat: 40.768169, Lon: -73.98668
#  prop_type: condo postal_code: 10011    Lat: 40.745291, Lon: -73.998884
#  prop_type: condo postal_code: 10024    Lat: 40.787888, Lon: -73.978588
#  prop_type: condo postal_code: 10022    Lat: 40.759534, Lon: -73.963145
#  prop_type: condo postal_code: 10022    Lat: 40.761618, Lon: -73.965385
#  prop_type: condo postal_code: 10065    Lat: 40.763137, Lon: -73.967043
#  prop_type: condo postal_code: 10023    Lat: 40.776786, Lon: -73.984306
#  prop_type: condo postal_code: 10026    Lat: 40.802031, Lon: -73.94851
#  prop_type: multi_family postal_code: 11207    Lat: 40.657359, Lon: -73.896299
#  prop_type: condo postal_code: 10028    Lat: 40.774173, Lon: -73.953544
#  prop_type: condo postal_code: 11201    Lat: 40.695273, Lon: -73.98901
#  prop_type: condo postal_code: 11211    Lat: 40.720337, Lon: -73.957691
#  prop_type: condo postal_code: 10014    Lat: 40.738494, Lon: -74.006231
#  prop_type: multi_family postal_code: 11223    Lat: 40.600326, Lon: -73.981431
#  prop_type: single_family postal_code: 11418    Lat: 40.69401, Lon: -73.843141
#  prop_type: condo postal_code: 11201    Lat: 40.698483, Lon: -73.995971
#  prop_type: condo postal_code: 10012    Lat: 40.728559, Lon: -73.995138
#  prop_type: condo postal_code: 10463    Lat: 40.880134, Lon: -73.911769
#  prop_type: single_family postal_code: 11427    Lat: 40.735741, Lon: -73.737464
#  prop_type: multi_family postal_code: 11421    Lat: 40.690516, Lon: -73.846936
#  prop_type: multi_family postal_code: 11102    Lat: 40.769119, Lon: -73.91846
#  prop_type: condo postal_code: 11421    Lat: 40.700135, Lon: -73.852323
#  prop_type: single_family postal_code: 10465    Lat: 40.838758, Lon: -73.822994
#  prop_type: condo postal_code: 10463    Lat: 40.889283, Lon: -73.910243
#  prop_type: multi_family postal_code: 10461    Lat: 40.836396, Lon: -73.837417
#  prop_type: condo postal_code: 11354    Lat: 40.768943, Lon: -73.829291
#  prop_type: multi_family postal_code: 10472    Lat: 40.830069, Lon: -73.855444
#  prop_type: condo postal_code: 11101    Lat: 40.751343, Lon: -73.939122
#  prop_type: condo postal_code: 10010    Lat: 40.742024, Lon: -73.986164
#  prop_type: condo postal_code: 10003    Lat: 40.730581, Lon: -73.989595
#  prop_type: condo postal_code: 11415    Lat: 40.708153, Lon: -73.828111
#  prop_type: single_family postal_code: 11415    Lat: 40.70558, Lon: -73.8235
#  prop_type: condo postal_code: 10305    Lat: 40.608662, Lon: -74.074505
#  prop_type: condo postal_code: 11415    Lat: 40.705001, Lon: -73.824134
#  prop_type: condo postal_code: 11362    Lat: 40.759115, Lon: -73.735051
#  prop_type: condo postal_code: 11374    Lat: 40.726374, Lon: -73.861822
#  prop_type: condo postal_code: 11373    Lat: 40.74428, Lon: -73.887396
#  prop_type: condo postal_code: 11238    Lat: 40.676853, Lon: -73.970055
#  prop_type: single_family postal_code: 11218    Lat: 40.651612, Lon: -73.974131
#  prop_type: single_family postal_code: 10314    Lat: 40.616939, Lon: -74.139
#  prop_type: single_family postal_code: 11364    Lat: 40.735982, Lon: -73.749152
#  prop_type: multi_family postal_code: 11203    Lat: 40.660279, Lon: -73.929992
#  prop_type: condo postal_code: 10128    Lat: 40.784581, Lon: -73.952501
#  prop_type: condo postal_code: 10012    Lat: 40.726888, Lon: -73.993396
#  prop_type: single_family postal_code: 11234    Lat: 40.606093, Lon: -73.91036
#  prop_type: single_family postal_code: 11001    Lat: 40.732026, Lon: -73.708595
#  prop_type: multi_family postal_code: 11385    Lat: 40.709088, Lon: -73.865679
#  prop_type: multi_family postal_code: 11223    Lat: 40.592508, Lon: -73.976392
#  prop_type: condo postal_code: 11235    Lat: 40.588213, Lon: -73.961819
#  prop_type: condo postal_code: 11249    Lat: 40.719958, Lon: -73.960225
#  prop_type: single_family postal_code: 11412    Lat: 40.701164, Lon: -73.759482
#  prop_type: single_family postal_code: 11357    Lat: 40.789772, Lon: -73.805356
#  prop_type: single_family postal_code: 11366    Lat: 40.722603, Lon: -73.809497
#  prop_type: multi_family postal_code: 11436    Lat: 40.668639, Lon: -73.789896
#  prop_type: condo postal_code: 11235    Lat: 40.589972, Lon: -73.959274
#  prop_type: multi_family postal_code: 11223    Lat: 40.596293, Lon: -73.981703
#  prop_type: multi_family postal_code: 11229    Lat: 40.596781, Lon: -73.95326
#  prop_type: single_family postal_code: 11374    Lat: 40.721708, Lon: -73.862699
#  prop_type: condo postal_code: 11373    Lat: 40.738913, Lon: -73.878644
#  prop_type: condo postal_code: 10065    Lat: 40.765284, Lon: -73.96903
#  prop_type: condo postal_code: 10003    Lat: 40.735853, Lon: -73.99251
#  prop_type: condo postal_code: 10028    Lat: 40.775655, Lon: -73.955089
#  prop_type: condo postal_code: 10023    Lat: 40.781127, Lon: -73.984492
#  prop_type: single_family postal_code: 10312    Lat: 40.559554, Lon: -74.179914
#  prop_type: condo postal_code: 10019    Lat: 40.765626, Lon: -73.977483
#  prop_type: condo postal_code: 11435    Lat: 40.701258, Lon: -73.809645
#  prop_type: condo postal_code: 10013    Lat: 40.720238, Lon: -74.005211
#  prop_type: condo postal_code: 10019    Lat: 40.767086, Lon: -73.983033
#  prop_type: condo postal_code: 11213    Lat: 40.676725, Lon: -73.937193
#  prop_type: condo postal_code: 10019    Lat: 40.7655, Lon: -73.979
#  prop_type: condo postal_code: 10014    Lat: 40.738669, Lon: -74.003146
#  prop_type: single_family postal_code: 11234    Lat: 40.609698, Lon: -73.936621
#  prop_type: single_family postal_code: 11235    Lat: 40.578752, Lon: -73.939031
#  prop_type: single_family postal_code: 11234    Lat: 40.60651, Lon: -73.910522
#  prop_type: single_family postal_code: 11369    Lat: 40.763116, Lon: -73.871211
#  prop_type: condo postal_code: 11378    Lat: 40.732171, Lon: -73.90072
#  prop_type: multi_family postal_code: 10462    Lat: 40.838102, Lon: -73.851959
#  prop_type: condo postal_code: 11354    Lat: 40.767178, Lon: -73.825383
#  prop_type: multi_family postal_code: 11208    Lat: 40.684833, Lon: -73.876271
#  prop_type: multi_family postal_code: 11236    Lat: 40.628551, Lon: -73.900929
#  prop_type: single_family postal_code: 11422    Lat: 40.659219, Lon: -73.739266
#  prop_type: multi_family postal_code: 11221    Lat: 40.687176, Lon: -73.915324
#  prop_type: multi_family postal_code: 11385    Lat: 40.700882, Lon: -73.894851
#  prop_type: condo postal_code: 11355    Lat: 40.75295, Lon: -73.820643
#  prop_type: condo postal_code: 10025    Lat: 40.799295, Lon: -73.962266
#  prop_type: condo postal_code: 10003    Lat: 40.7305, Lon: -73.993074
#  prop_type: condo postal_code: 11375    Lat: 40.71955, Lon: -73.846301
#  prop_type: condo postal_code: 11375    Lat: 40.721401, Lon: -73.84429
#  prop_type: condo postal_code: 11374    Lat: 40.728658, Lon: -73.862255
#  prop_type: condo postal_code: 10466    Lat: 40.891887, Lon: -73.856325
#  prop_type: condo postal_code: 10032    Lat: 40.832667, Lon: -73.940226
#  prop_type: condo postal_code: 11201    Lat: 40.695552, Lon: -73.992106
#  prop_type: condo postal_code: 10014    Lat: 40.731025, Lon: -74.010022
#  prop_type: condo postal_code: 10024    Lat: 40.785959, Lon: -73.975891
#  prop_type: condo postal_code: 10022    Lat: 40.756643, Lon: -73.96165
#  prop_type: condo postal_code: 10038    Lat: 40.709112, Lon: -74.006344
#  prop_type: condo postal_code: 10065    Lat: 40.764441, Lon: -73.962655
#  prop_type: condo postal_code: 10011    Lat: 40.739122, Lon: -73.993816
#  prop_type: multi_family postal_code: 10466    Lat: 40.89453, Lon: -73.857321
#  prop_type: condo postal_code: 10011    Lat: 40.738888, Lon: -74.001298
#  prop_type: condo postal_code: 11243    Lat: 40.685513, Lon: -73.977721
#  prop_type: condo postal_code: 10075    Lat: 40.77333, Lon: -73.95638
#  prop_type: condo postal_code: 11373    Lat: 40.743634, Lon: -73.880526
#  prop_type: condo postal_code: 10463    Lat: 40.888271, Lon: -73.916254
#  prop_type: multi_family postal_code: 11208    Lat: 40.664031, Lon: -73.880351
#  prop_type: single_family postal_code: 11414    Lat: 40.652006, Lon: -73.842166
#  prop_type: condo postal_code: 11373    Lat: 40.746093, Lon: -73.882117
#  prop_type: condo postal_code: 10031    Lat: 40.82689, Lon: -73.944227
#  prop_type: condo postal_code: 11215    Lat: 40.660271, Lon: -73.989665
#  prop_type: single_family postal_code: 11412    Lat: 40.694675, Lon: -73.75558
#  prop_type: condo postal_code: 11354    Lat: 40.764304, Lon: -73.831217
#  prop_type: single_family postal_code: 10308    Lat: 40.559344, Lon: -74.148963
#  prop_type: multi_family postal_code: 11417    Lat: 40.675622, Lon: -73.849913
#  prop_type: multi_family postal_code: 11412    Lat: 40.69536, Lon: -73.748403
#  prop_type: condo postal_code: 10303    Lat: 40.621567, Lon: -74.166518
#  prop_type: condo postal_code: 11414    Lat: 40.666572, Lon: -73.846243
#  prop_type: condo postal_code: 10023    Lat: 40.782112, Lon: -73.983287
#  prop_type: condo postal_code: 11201    Lat: 40.701545, Lon: -73.995869
#  prop_type: condo postal_code: 10462    Lat: 40.83611, Lon: -73.858932
#  prop_type: single_family postal_code: 10301    Lat: 40.636595, Lon: -74.077806
#  prop_type: single_family postal_code: 10301    Lat: 40.620904, Lon: -74.10881
#  prop_type: condo postal_code: 11356    Lat: 40.793352, Lon: -73.8447
#  prop_type: multi_family postal_code: 11412    Lat: 40.695329, Lon: -73.748389
#  prop_type: condo postal_code: 11230    Lat: 40.630173, Lon: -73.958094
#  prop_type: single_family postal_code: 11204    Lat: 40.615891, Lon: -73.995939
#  prop_type: multi_family postal_code: 10469    Lat: 40.867928, Lon: -73.846509
#  prop_type: condo postal_code: 11372    Lat: 40.751252, Lon: -73.88127
#  prop_type: condo postal_code: 10301    Lat: 40.639267, Lon: -74.074049
#  prop_type: condo postal_code: 10010    Lat: 40.73889, Lon: -73.987904
#  prop_type: condo postal_code: 10010    Lat: 40.739103, Lon: -73.982268
#  prop_type: condo postal_code: 10019    Lat: 40.767173, Lon: -73.985076
#  prop_type: condo postal_code: 10023    Lat: 40.777103, Lon: -73.986244
#  prop_type: condo postal_code: 11372    Lat: 40.75106, Lon: -73.881531
#  prop_type: multi_family postal_code: 11103    Lat: 40.761327, Lon: -73.913432
#  prop_type: multi_family postal_code: 10314    Lat: 40.617054, Lon: -74.13091
#  prop_type: condo postal_code: 11374    Lat: 40.73183, Lon: -73.856408
#  prop_type: condo postal_code: 11364    Lat: 40.746345, Lon: -73.75674
#  prop_type: land postal_code: 11418    Lat: 40.702763, Lon: -73.838635
#  prop_type: single_family postal_code: 10305    Lat: 40.612757, Lon: -74.069801
#  prop_type: condo postal_code: 10010    Lat: 40.739961, Lon: -73.990361
#  prop_type: condo postal_code: 11230    Lat: 40.622382, Lon: -73.969473
#  prop_type: condo postal_code: 10016    Lat: 40.74399, Lon: -73.97549
#  prop_type: condo postal_code: 11201    Lat: 40.688589, Lon: -73.996994
#  prop_type: single_family postal_code: 10314    Lat: 40.61046, Lon: -74.169412
#  prop_type: single_family postal_code: 10308    Lat: 40.55534, Lon: -74.155915
#  prop_type: condo postal_code: 10038    Lat: 40.709112, Lon: -74.006344
#  prop_type: condo postal_code: 11205    Lat: 40.692568, Lon: -73.965196
#  prop_type: condo postal_code: 10038    Lat: 40.709112, Lon: -74.006344
#  prop_type: condo postal_code: 11226    Lat: 40.64122, Lon: -73.962822
#  prop_type: condo postal_code: 10038    Lat: 40.709112, Lon: -74.006344
#  prop_type: condo postal_code: 11233    Lat: 40.683455, Lon: -73.926448
#  prop_type: condo postal_code: 10037    Lat: 40.813126, Lon: -73.937539
#  prop_type: condo postal_code: 11230    Lat: 40.622014, Lon: -73.965041
#  prop_type: single_family postal_code: 10306    Lat: 40.563366, Lon: -74.106934
#  prop_type: multi_family postal_code: 11379    Lat: 40.726264, Lon: -73.879826
#  prop_type: condo postal_code: 11368    Lat: 40.747907, Lon: -73.867953
#  prop_type: multi_family postal_code: 11229    Lat: 40.594639, Lon: -73.957362
#  prop_type: multi_family postal_code: 11235    Lat: 40.586412, Lon: -73.942449
#  prop_type: condo postal_code: 10128    Lat: 40.780704, Lon: -73.955986
#  prop_type: condo postal_code: 11201    Lat: 40.693513, Lon: -74.000182
#  prop_type: condo postal_code: 11354    Lat: 40.767948, Lon: -73.831309
#  prop_type: multi_family postal_code: 11373    Lat: 40.734264, Lon: -73.886184
#  prop_type: single_family postal_code: 11358    Lat: 40.764288, Lon: -73.79173
#  prop_type: condo postal_code: 11375    Lat: 40.722375, Lon: -73.840539
#  prop_type: condo postal_code: 10024    Lat: 40.787888, Lon: -73.978588
#  prop_type: single_family postal_code: 10314    Lat: 40.612532, Lon: -74.151606
#  prop_type: condo postal_code: 10023    Lat: 40.779944, Lon: -73.983276
#  prop_type: single_family postal_code: 11215    Lat: 40.671737, Lon: -73.989304
#  prop_type: condo postal_code: 10011    Lat: 40.742105, Lon: -74.000689
#  prop_type: single_family postal_code: 10314    Lat: 40.612377, Lon: -74.151121
#  prop_type: multi_family postal_code: 11355    Lat: 40.745926, Lon: -73.830995
#  prop_type: condo postal_code: 10017    Lat: 40.751769, Lon: -73.969927
#  prop_type: condo postal_code: 10021    Lat: 40.766187, Lon: -73.957575
#  prop_type: condo postal_code: 11693    Lat: 40.58484, Lon: -73.813951
#  prop_type: single_family postal_code: 10301    Lat: 40.611429, Lon: -74.107078
#  prop_type: condo postal_code: 11427    Lat: 40.73005, Lon: -73.749384
#  prop_type: condo postal_code: 11364    Lat: 40.737206, Lon: -73.742935
#  prop_type: multi_family postal_code: 11214    Lat: 40.609532, Lon: -73.997707
#  prop_type: single_family postal_code: 11214    Lat: 40.603597, Lon: -74.013403
#  prop_type: single_family postal_code: 10309    Lat: 40.546282, Lon: -74.219257
#  prop_type: multi_family postal_code: 10301    Lat: 40.639996, Lon: -74.082995
#  prop_type: multi_family postal_code: 11219    Lat: 40.634419, Lon: -74.002138
#  prop_type: single_family postal_code: 11362    Lat: 40.762251, Lon: -73.722635
#  prop_type: single_family postal_code: 11379    Lat: 40.716943, Lon: -73.875986
#  prop_type: condo postal_code: 11368    Lat: 40.750231, Lon: -73.856898
#  prop_type: single_family postal_code: 10302    Lat: 40.623517, Lon: -74.133594
#  prop_type: condo postal_code: 10016    Lat: 40.745056, Lon: -73.985893
#  prop_type: condo postal_code: 10007    Lat: 40.714149, Lon: -74.009054
#  prop_type: single_family postal_code: 11216    Lat: 40.670918, Lon: -73.948537

# %%
# Calling DataFrame constructor    
# create dataframe with list of values
realtor_df = pd.DataFrame(list(zip(prop_type, city, postal_code, lat, lon, building_size, price)), 
               columns =['prop_type', 'city', 'postal_code', 'lat', 'lon', 'size (sqft)', 'price']) 
realtor_df
# Out:
#          prop_type           city postal_code        lat        lon  \
# 0            condo       New York       11238  40.675320 -73.958316
# 1    single_family   Saint Albans          NA  40.698966 -73.768920
# 2    single_family       Flushing       11375  40.709773 -73.855658
# 3    single_family  Staten Island       10306  40.572692 -74.115587
# 4            condo        Bayside          NA  40.746345 -73.756740
# ..             ...            ...         ...        ...        ...
# 195          condo         Corona       11368  40.750231 -73.856898
# 196  single_family  Staten Island       10302  40.623517 -74.133594
# 197          condo       New York       10016  40.745056 -73.985893
# 198          condo       New York          NA  40.714149 -74.009054
# 199  single_family       Brooklyn       11216  40.670918 -73.948537
#
#     size (sqft)    price
# 0           676   840000
# 1            NA   565000
# 2          1216  1350000
# 3          2640   699999
# 4            NA   315000
# ..          ...      ...
# 195         795   588000
# 196        1810   649999
# 197         991  1450000
# 198          NA  2500000
# 199        3304  2200000
#
# [200 rows x 7 columns]

# %%
import http.client

conn = http.client.HTTPSConnection("realtor.p.rapidapi.com")

headers = {
    'x-rapidapi-key': "===============================",
    'x-rapidapi-host': "================="
    }

conn.request("GET", "/properties/v2/list-for-sale?city=New%20York%20City&limit=200&offset=0&state_code=NY&sort=relevance", headers=headers)

res = conn.getresponse()
data = res.read()

print(data.decode("utf-8"))
