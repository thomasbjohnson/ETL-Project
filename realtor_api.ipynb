# %%
import requests
import pandas as pd
import json

url = "https://realtor.p.rapidapi.com/properties/v2/list-for-sale"

querystring = {"city":"New York City","limit":"200","offset":"0","state_code":"NY","sort":"relevance"}

headers = {
    'x-rapidapi-key': "    'x-rapidapi-host': "    }

json = response.json()
df = pd.DataFrame.from_dict(json)
response = requests.request("GET", url, headers=headers, params=querystring)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-794f44cae276> in <module>
#      13
#      14 json = response.json()
# ---> 15 df = pd.DataFrame.from_dict(json)
#      16 response = requests.request("GET", url, headers=headers, params=querystring)
#      17
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in from_dict(cls, data, orient, dtype, columns)
#    1307             raise ValueError("only recognize index or columns for orient")
#    1308
# -> 1309         return cls(data, index=index, columns=columns, dtype=dtype)
#    1310
#    1311     def to_numpy(
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     466
#     467         elif isinstance(data, dict):
# --> 468             mgr = init_dict(data, index, columns, dtype=dtype)
#     469         elif isinstance(data, ma.MaskedArray):
#     470             import numpy.ma.mrecords as mrecords
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\construction.py in init_dict(data, index, columns, dtype)
#     281             arr if not is_datetime64tz_dtype(arr) else arr.copy() for arr in arrays
#     282         ]
# --> 283     return arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     284
#     285
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\construction.py in arrays_to_mgr(arrays, arr_names, index, columns, dtype, verify_integrity)
#      76         # figure out the index, if necessary
#      77         if index is None:
# ---> 78             index = extract_index(arrays)
#      79         else:
#      80             index = ensure_index(index)
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\construction.py in extract_index(data)
#     398
#     399             if have_dicts:
# --> 400                 raise ValueError(
#     401                     "Mixing dicts with non-Series may lead to ambiguous ordering."
#     402                 )
#
# ValueError: Mixing dicts with non-Series may lead to ambiguous ordering.

# %%
import http.client

conn = http.client.HTTPSConnection("realtor.p.rapidapi.com")

headers = {
    'x-rapidapi-key': "===============================",
    'x-rapidapi-host': "================="
    }

conn.request("GET", "/properties/v2/list-for-sale?city=New%20York%20City&limit=200&offset=0&state_code=NY&sort=relevance", headers=headers)

res = conn.getresponse()
data = res.read()

print(data.decode("utf-8"))
# Out:
# ,"id":"PRCH-3272675","plan_id":null,"abbreviation":"RBNY","type":"mls"},"data_source_name":"mls"},{"property_id":"M4033732947","listing_id":"2922216808","products":["co_broke"],"rdc_web_url":"https://www.realtor.com/realestateandhomes-detail/70-Remsen-St-2AB_Brooklyn_NY_11201_M40337-32947","prop_type":"condo","prop_sub_type":"coop","address":{"city":"Brooklyn","line":"70 Remsen St Unit 2AB","postal_code":"11201","state_code":"NY","state":"New York","county":"Kings","fips_code":"36047","county_needed_for_uniq":false,"time_zone":"America/New_York","lat":40.69416,"lon":-73.99588,"neighborhood_name":"Northwestern Brooklyn"},"branding":{"listing_office":{"list_item":{"name":null,"photo":null,"phone":null,"slogan":null,"show_realtor_logo":false,"link":null,"accent_color":null}}},"prop_status":"for_sale","price":1485000,"baths_full":2,"baths":2,"beds":2,"open_houses":[{"start_date":"2021-03-28T15:00:00.000Z","end_date":"2021-03-28T17:00:00.000Z","time_zone":"EST","dst":true}],"agents":[{"primary":true}],"office":{"id":"640e8f327f40322ed763b53f4653bc75"},"last_update":"2021-03-17T23:50:11Z","client_display_flags":{"presentation_status":"for_sale","is_showcase":false,"lead_form_phone_required":true,"price_change":0,"is_co_broke_email":true,"has_open_house":true,"is_co_broke_phone":false,"is_new_listing":true,"is_new_plan":false,"is_turbo":false,"is_office_standard_listing":false,"suppress_map_pin":false,"show_contact_a_lender_in_lead_form":false,"show_veterans_united_in_lead_form":false,"is_showcase_choice_enabled":false},"lead_forms":{"form":{"name":{"required":true,"minimum_character_count":1},"email":{"required":true,"minimum_character_count":5},"phone":{"required":true,"minimum_character_count":10,"maximum_character_count":11},"message":{"required":false,"minimum_character_count":0},"show":true},"show_agent":false,"show_broker":false,"show_builder":false,"show_contact_a_lender":false,"show_veterans_united":false,"form_type":"classic","lead_type":"co_broke","is_lcm_enabled":false,"flip_the_market_enabled":false,"show_text_leads":true,"cashback_enabled":false,"smarthome_enabled":false},"photo_count":10,"thumbnail":"https://ap.rdcpix.com/e4fe82039a7dca75438b6067168cd917l-m1363267627x.jpg","page_no":5,"rank":21,"list_tracking":"type|property|data|prop_id|4033732947|list_id|2922216808|page|rank|list_branding|listing_agent|listing_office|property_status|product_code|advantage_code^5|L|0|0|35T|G|0^^$0|1|2|$3|4|5|6|7|F|8|G|9|$A|H|B|I]|C|J|D|K|E|L]]","mls":{"name":"REBNY","id":"PRCH-3150803","plan_id":null,"abbreviation":"RBNY","type":"mls"},"data_source_name":"mls"},{"property_id":"M9803512696","listing_id":"2923141181","products":["co_broke"],"rdc_web_url":"https://www.realtor.com/realestateandhomes-detail/73-Gold-St_Brooklyn_NY_11201_M98035-12696","prop_type":"multi_family","address":{"city":"Brooklyn","line":"73 Gold St","postal_code":"11201","state_code":"NY","state":"New York","county":"Kings","fips_code":"36047","county_needed_for_uniq":false,"lat":40.702774,"lon":-73.982517,"neighborhood_name":"Northwestern Brooklyn"},"branding":{"listing_office":{"list_item":{"name":null,"photo":null,"phone":null,"slogan":null,"show_realtor_logo":false,"link":null,"accent_color":null}}},"prop_status":"for_sale","price":4450000,"baths_full":5,"baths":5,"beds":4,"building_size":{"size":2812,"units":"sqft"},"agents":[{"primary":true}],"office":{"id":"640e8f327f40322ed763b53f4653bc75"},"last_update":"2021-03-16T02:01:55Z","client_display_flags":{"presentation_status":"for_sale","is_showcase":false,"lead_form_phone_required":true,"price_change":0,"is_co_broke_email":true,"has_open_house":false,"is_co_broke_phone":false,"is_new_listing":true,"is_new_plan":false,"is_turbo":false,"is_office_standard_listing":false,"suppress_map_pin":false,"show_contact_a_lender_in_lead_form":false,"show_veterans_united_in_lead_form":false,"is_showcase_choice_enabled":false},"lead_forms":{"form":{"name":{"required":true,"minimum_character_count":1},"email":{"required":true, ...
